# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %% [markdown]
# ## State of variables

# %%
import numpy as np

# %% [markdown]
# ## Matrix multiplication

# %% [markdown]
# $X = A \times B$

# %%
arr = list()
for _ in range(1, 100):
    arr += list(range(1, 100))

# %%
arr

# %%
arr = [list(range(1, 100)) for _ in range(1, 100)]

# %%
mt = np.array(arr)

# %%
mt

# %%
mt1 = np.random.rand(800, 400)
mt2 = np.random.rand(400, 1200)

# %%
# %timeit mt1 @ mt2

# %%
ls1 = mt1.tolist()
ls2 = mt2.tolist()
